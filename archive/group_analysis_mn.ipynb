# %%
import mne
import glob
#import matplotlib.pyplot as plt
import numpy as np
#mne.viz.set_browser_backend('qt')
#%matplotlib qt
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: The MNE-Python config file (/home/james/.mne/mne-python.json) is not a valid JSON file and might be corrupted

# %%
project_path = "/home/james/q1k/pilot/q1k-external-pilot/"
pylossless_path = "derivatives/pylossless/"
postproc_path = "derivatives/q1k_postproc/"
task_id = "mn"
#task_id_out = "mn"
#subject_id = '010'
#session_id = '02'

#bids_path = mne_bids.BIDSPath(
#    subject=subject_id, session=session_id, task=task_id_out, run="1", datatype="eeg", suffix="eeg",root=project_path + pylossless_path
#)
#print(bids_path)

# %%
conditions = ['mmns','mmnt']

# %%
erp_files = glob.glob(project_path + pylossless_path + postproc_path + 'erp_fif_files/mn/*_erp.fif')

# %%
erp_files
# Out:
# ['/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-008_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-030_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-012_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-02_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-02_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-02_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-018_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-02_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-032_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-02_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-029_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-009_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-028_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-020_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-024_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-02_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-004_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-015_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-023_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-096_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-01_task-mn_run-1_eeg_erp.fif',
#  '/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-01_task-mn_run-1_eeg_erp.fif']

# %%
evokeds = {}

for idx, c in enumerate(conditions):
    evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]

evokeds
# Out:
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-008_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-008_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 11 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-030_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 69 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 11 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-012_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 51 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-02_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-030_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-012_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 44 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 6 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 6 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 46 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-02_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 7 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-018_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 54 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-032_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-018_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-032_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 66 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 14 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 43 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 7 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-029_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 40 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-029_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 6 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-009_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 51 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-028_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 47 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-020_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-009_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-028_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-020_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 55 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 5 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-024_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 52 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 154 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 27 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-024_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 90 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 16 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 43 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 7 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-004_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 68 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-004_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-015_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-023_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 53 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-015_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-023_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-096_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-096_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 39 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 4 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-008_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 11 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-030_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 69 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 11 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-012_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-008_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-030_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-012_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 51 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 44 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 6 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 6 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-02_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-014_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 46 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 7 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-018_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-018_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 54 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-032_ses-01_task-mn_run-1_eeg_erp.fif ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-002_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-032_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 66 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 14 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 43 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 7 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-029_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 40 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-029_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 6 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-009_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 51 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-028_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 47 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-020_ses-01_task-mn_run-1_eeg_erp.fif ...
# ...
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-006_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 90 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 16 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-02_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 43 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 7 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-004_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 68 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-02_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-004_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-015_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 56 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-010_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-015_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-023_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 53 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 10 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-096_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-023_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-096_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#         0 CTF compensation matrices available
#         nave = 9 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 49 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 8 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-01_task-mn_run-1_eeg_erp.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/standard/disp/mmns)
#         0 CTF compensation matrices available
#         nave = 39 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-038_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
# /tmp/ipykernel_6462/4039943032.py:4: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/erp_fif_files/mn/sub-052_ses-01_task-mn_run-1_eeg_erp.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evokeds[c] = [mne.read_evokeds(d)[idx] for d in erp_files]
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms (mmn/target/disp/mmnt)
#         0 CTF compensation matrices available
#         nave = 4 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# Loaded Evoked data is baseline-corrected (baseline: [-1, 0] s)
# {'mmns': [<Evoked | 'mmn/standard/disp/mmns' (average, N=49), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=69), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=51), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=44), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=49), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=46), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=56), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=56), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=54), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=66), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=43), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=40), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=51), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=47), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=55), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=52), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=154), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=90), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=43), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=68), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=56), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=56), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=53), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=49), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=49), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/standard/disp/mmns' (average, N=39), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>],
#  'mmnt': [<Evoked | 'mmn/target/disp/mmnt' (average, N=11), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=11), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=10), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=6), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=6), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=9), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=7), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=8), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=8), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=14), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=7), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=6), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=9), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=10), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=5), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=10), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=27), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=16), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=7), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=9), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=8), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=8), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=10), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=9), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=8), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>,
#   <Evoked | 'mmn/target/disp/mmnt' (average, N=4), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>]}

# %%
roi = ['E6']

color_dict = {'mmns':'blue', 'mmnt':'red'}
linestyle_dict = {'mmns':'-', 'mmnt':'-'}


mne.viz.plot_compare_evokeds(evokeds,
                             combine='mean',
                             legend='lower right',
                             picks=roi, show_sensors='upper right',
                             colors=color_dict,
                             linestyles=linestyle_dict,
                             title='standard vs. target ERPs'
                            )
#plt.show()
# Out:
# combining channels using "mean"
# /tmp/ipykernel_6462/545515242.py:7: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   mne.viz.plot_compare_evokeds(evokeds,
# combining channels using "mean"
# [<Figure size 800x600 with 2 Axes>]

# %%
diff_waves = []
for i in range(len(erp_files)):
    diff_waves.append(mne.combine_evoked([evokeds['distractor'][i], evokeds['target'][i]],
                                          weights=[1, -1]
                                         )
                     )

diff_waves

# %%
contrast = 'distractor-target'
mne.viz.plot_compare_evokeds({contrast:diff_waves}, combine='mean',
                            legend=None,
                            picks=roi, show_sensors='upper right',
                            title=contrast
                            )
plt.show()

# %%
mne.viz.plot_evoked_topomap(mne.grand_average(diff_waves), 
                            times=.500, average=1.4,
                            size=3
                           )
plt.show()

# %% [markdown]
# t-test

# %%
evoked_data = np.array([np.mean(e.get_data(picks='E71', tmin=-0.4, tmax=1.0), axis=1) for e in diff_waves])

# %%
from scipy import stats 

t, pval = stats.ttest_1samp(evoked_data, 0)
print('Difference t = ', str(round(t[0], 2)), 'p = ', str(round(pval[0], 4)))

# %%
from mne.stats import permutation_t_test

# %%
evoked_data = np.array([np.mean(e.get_data(tmin=-0.4, tmax=1.0), axis=1) for e in diff_waves])

# %%
n_permutations = 50000
T0, p_values, H0 = permutation_t_test(evoked_data, n_permutations, tail=-1)

# %%
p_values

# %%
epoch_files = glob.glob('erp_fif_files/ap/*_ep.fif')
epoch_files

# %%
#epochs = {}

#for idx, c in enumerate(conditions):
#    epochs[c] = [mne.read_epochs(d)[idx] for d in epoch_files]

#epochs

epochs = mne.read_epochs('erp_fif_files/ap/004_1_ap_ep.fif')

# %%
from mne.time_frequency import (
    tfr_multitaper,
    tfr_stockwell,
    tfr_morlet,
    tfr_array_morlet,
    AverageTFR,
)
from mne.viz import centers_to_edges

# %%
freqs = np.arange(2.0, 50, 3.0)
vmin, vmax = -3.0, 3.0  # Define our color limits.

#fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
all_n_cycles = [1, 3, freqs / 2.0]
for n_cycles, ax in zip(all_n_cycles, axs):
    power, itc = tfr_morlet(epochs, freqs=freqs, n_cycles=n_cycles, return_itc=True)
    power.plot(
        [0],
        baseline=(0.0, 0.1),
        mode="mean",
        vmin=vmin,
        vmax=vmax,
        axes=ax,
        show=False,
        colorbar=False,
    )
    n_cycles = "scaled by freqs" if not isinstance(n_cycles, int) else n_cycles
    ax.set_title(f"Sim: Using Morlet wavelet, n_cycles = {n_cycles}")
plt.tight_layout()

# %%
freqs = np.arange(2.0, 50, 3.0)
power, itc = tfr_morlet(epochs, freqs=freqs, n_cycles=1, return_itc=True)

# %%
freqs = np.array([4,6,8,10,12,16,32,36,40,48])
n_cycles = freqs / 2.0  # different number of cycle per frequency
power, itc = mne.time_frequency.tfr_morlet(
    epochs,
    freqs=freqs,
    n_cycles=n_cycles,
    use_fft=True,
    return_itc=True,
    decim=3,
    n_jobs=None,
)

# %%
power

# %%
power.plot(picks='E6', baseline=(-0.5, 0), mode="logratio", title='power')

# %%
itc.plot(picks='E6')
