# %%
import mne
import glob
import matplotlib.pyplot as plt
import numpy as np
# mne.viz.set_browser_backend('qt')
#%matplotlib qt

# %%
project_path = "/home/james/q1k/pilot/q1k-external-pilot/"
pylossless_path = "derivatives/pylossless/"
postproc_path = "derivatives/q1k_postproc/"

# %%
conditions = ['target','distractor']
roi = ['E6']
decim = 2
freqs = np.arange(2, 50, 2)
n_cycles = freqs / 2

epoch_files = glob.glob(project_path + pylossless_path + postproc_path + 'epoch_fif_files/as/*epochs.fif')
for item in epoch_files:
   print("[", item, "] ")
# Out:
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-015_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-030_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-096_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-024_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-013_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-026_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-032_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-010_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-028_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-009_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-038_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-02_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-012_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-017_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-02_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-02_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-018_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-052_ses-01_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-038_ses-02_task-as_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-004_ses-02_task-as_run-1_eeg_epochs.fif ]

# %%
epoch_files = glob.glob(project_path + pylossless_path + postproc_path + 'epoch_fif_files/as/*epochs.fif')
averaging_dict = {labels:[] for labels in conditions}

for filepath in epoch_files:
    print(filepath)
    new_epoch = mne.read_epochs(filepath)
    for condition in conditions:
        power, itc = mne.time_frequency.tfr_morlet(new_epoch[condition].pick(roi), n_cycles=n_cycles, return_itc=True, freqs=freqs, decim=decim)
        averaging_dict[condition].append((new_epoch[condition].average(), power, itc))
# Out:
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-015_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-015_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-015_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 85 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 37 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-030_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-030_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-030_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-096_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-096_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-096_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 46 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-024_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-024_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-024_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-013_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-013_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-013_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-026_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-026_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-026_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 139 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-032_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-032_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-032_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-010_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-010_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-010_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-028_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-028_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-028_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-009_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-009_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-009_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 83 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-038_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-038_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-038_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 49 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-02_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-02_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-006_ses-02_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-012_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-012_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-012_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 53 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-017_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-017_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-017_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-02_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-02_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-002_ses-02_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-02_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-02_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-014_ses-02_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 38 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-018_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-018_ses-01_task-as_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-018_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 50 matching events found
# No baseline correction applied
# 0 projection items activated
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-052_ses-01_task-as_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-052_ses-01_task-as_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_27589/1530660939.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/as/sub-052_ses-01_task-as_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
def condition_summary(condition_label):
    print('Working on: ', condition_label)
    grand_average = mne.grand_average([item[0] for item in averaging_dict[condition_label]])
    display(grand_average)
    grand_average.plot()
    times = np.arange(-1.0, 2.0, .1)
    fig = grand_average.plot_topomap(times=times, colorbar=True)
    fig.suptitle(condition_label)

for condition in conditions:
    condition_summary(condition)
# Out:
# Working on:  target
# Identifying common channels ...
# <Evoked | 'Grand average (n = 21)' (average, N=21), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>
# /tmp/ipykernel_27589/3457014730.py:7: RuntimeWarning: More than 25 topomaps plots requested. This might take a while.
#   fig = grand_average.plot_topomap(times=times, colorbar=True)
# <MNEFigure size 4500x220 with 31 Axes>
# Working on:  distractor
# Identifying common channels ...
# <Evoked | 'Grand average (n = 21)' (average, N=21), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>
# /tmp/ipykernel_27589/3457014730.py:7: RuntimeWarning: More than 25 topomaps plots requested. This might take a while.
#   fig = grand_average.plot_topomap(times=times, colorbar=True)
# <MNEFigure size 4500x220 with 31 Axes>

# %%
color_dict = {'target':'blue', 'distractor':'red'}
linestyle_dict = {'target':'-', 'distractor':'-'}

evokeds = {
    'target': [item[0] for item in averaging_dict['target']],
    'distractor': [item[0] for item in averaging_dict['distractor']],
}

mne.viz.plot_compare_evokeds(evokeds,
                             combine='mean',
                             legend='lower right',
                             picks=roi, show_sensors='upper right',
                             colors=color_dict,
                             linestyles=linestyle_dict,
                             title='target vs. distractor ERPs'
                            )
# Out:
# combining channels using "mean"
# /tmp/ipykernel_27589/1051595119.py:9: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   mne.viz.plot_compare_evokeds(evokeds,
# combining channels using "mean"
# [<Figure size 800x600 with 2 Axes>]

# %%
# True for ERSP, False for ITC
def do_power_plotting(ersp=True):
    indexer = 1 if ersp else 2
    cond1 = mne.grand_average([item[indexer] for item in averaging_dict['target']])
    cond2 = mne.grand_average([item[indexer] for item in averaging_dict['distractor']])

    epochs_power_1 = np.array([item[indexer].data for item in averaging_dict['target']])[:, 0, :, :]
    epochs_power_2 = np.array([item[indexer].data for item in averaging_dict['distractor']])[:, 0, :, :]


    #times = 1e3 * epochs_power_1.times  # change unit to ms
    times = 1e3 * averaging_dict['target'][0][1].times
    fig1, (ax1t, ax1b) = plt.subplots(2, 1, figsize=(6, 4))
    fig1.subplots_adjust(0.12, 0.08, 0.96, 0.94, 0.2, 0.43)

    ax1t.imshow(
        epochs_power_1.mean(axis=0),
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="RdBu_r",
    )

    ax1b.imshow(
        epochs_power_2.mean(axis=0),
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="RdBu_r",
    )

    ax1t.set_ylabel("Frequency (Hz)")
    ax1t.set_title(f"target Induced power")
    ax1b.set_title(f"target Inter Trial Coherence")
    ax1b.set_xlabel("Time (ms)")


    F_obs, clusters, cluster_p_values, H0 = mne.stats.permutation_cluster_test(
        [epochs_power_1, epochs_power_2],
        out_type="mask",
        n_permutations=100,
        threshold=6.0,
        tail=0,
    ) # returns F difference, sampled, zscore

    # Grab any ERSP type timing window and use it to scale to ms
    times = 1e3 * averaging_dict['target'][0][1].times

    evoked_power_contrast = epochs_power_1.mean(axis=0) - epochs_power_2.mean(axis=0)
    signs = np.sign(evoked_power_contrast)

    F_obs_plot = np.nan * np.ones_like(F_obs)
    for c, p_val in zip(clusters, cluster_p_values):
        if p_val <= 0.05:
            F_obs_plot[c] = F_obs[c] * signs[c]
    max_F = np.nanmax(abs(F_obs_plot))

    fig, (ax, ax2) = plt.subplots(2, 1, figsize=(6, 4))
    ax.imshow(
        F_obs,
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="gray",
    )

    ax.imshow(
        F_obs_plot,
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="RdBu_r",
        vmin=-max_F,
        vmax=max_F,
    )
    ax.set_xlabel("Time (ms)")
    ax.set_ylabel("Frequency (Hz)")
    ax.set_title("Induced power")

    evoked_contrast = mne.combine_evoked(
        [cond1, cond2], weights=[1, -1]
    )
    evoked_contrast.plot(axes=ax2)

# %%
do_power_plotting(ersp=True)
do_power_plotting(ersp=False)
# Out:
# Identifying common channels ...
# Identifying common channels ...
# stat_fun(H1): min=0.000000 max=2.707371
# Running initial clustering …
# Found 0 clusters
# No baseline correction applied
# /tmp/ipykernel_27589/2708857854.py:38: RuntimeWarning: No clusters found, returning empty H0, clusters, and cluster_pv
#   F_obs, clusters, cluster_p_values, H0 = mne.stats.permutation_cluster_test(
# /tmp/ipykernel_27589/2708857854.py:56: RuntimeWarning: All-NaN slice encountered
#   max_F = np.nanmax(abs(F_obs_plot))
# Identifying common channels ...
# Identifying common channels ...
# stat_fun(H1): min=0.000000 max=19.329814
# Running initial clustering …
# Found 34 clusters
# 100%|██████████| Permuting : 99/99 [00:02<00:00,   38.06it/s]
# No baseline correction applied

# %%
# !jupyter nbconvert --output {"session_reports/group_as.html"} --TagRemovePreprocessor.remove_all_outputs_tags='{"exclude"}' --no-input --to html group_erp_tf_as.ipynb
# Out:
# [NbConvertApp] Converting notebook group_erp_tf_as.ipynb to html
# [NbConvertApp] Writing 3065108 bytes to session_reports/group_as.html
