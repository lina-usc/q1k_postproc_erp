# %%
import mne
import glob
import matplotlib.pyplot as plt
import numpy as np
# mne.viz.set_browser_backend('qt')
#%matplotlib qt

# %%
project_path = "/home/james/q1k/pilot/q1k-external-pilot/"
pylossless_path = "derivatives/pylossless/"
postproc_path = "derivatives/q1k_postproc/"

# %%
conditions = ['sv06','sv15']
roi = ['E84']
decim = 2
freqs = np.arange(2, 50, 2)
n_cycles = freqs / 2

epoch_files = glob.glob(project_path + pylossless_path + postproc_path + 'epoch_fif_files/vp/*epochs.fif')
for item in epoch_files:
   print("[", item, "] ")
# Out:
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-020_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-015_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-02_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-02_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-004_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-008_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-018_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-032_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-012_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-017_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-096_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-02_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-024_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-028_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-02_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-009_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-023_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-029_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-02_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-013_ses-01_task-vp_run-1_eeg_epochs.fif ]
# [ /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-02_task-vp_run-1_eeg_epochs.fif ]

# %%
epoch_files = glob.glob(project_path + pylossless_path + postproc_path + 'epoch_fif_files/vp/*epochs.fif')
averaging_dict = {labels:[] for labels in conditions}

for filepath in epoch_files:
    print(filepath)
    new_epoch = mne.read_epochs(filepath)
    # the following is to select the first 50% of epochs
    #nepochs = len(new_epoch)
    #print("NTrials = " + str(nepochs))
    #trial_cap = round(nepochs/2)
    #print("trial cap = " + str(trial_cap))
    #new_epoch = new_epoch[:trial_cap]
    for condition in conditions:
        power, itc = mne.time_frequency.tfr_morlet(new_epoch[condition].pick(roi), n_cycles=n_cycles, return_itc=True, freqs=freqs, decim=decim)
        averaging_dict[condition].append((new_epoch[condition].average(), power, itc))
# Out:
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-020_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-020_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-020_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 105 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 105
# trial cap = 52
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-015_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-015_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-015_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 117 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 117
# trial cap = 58
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 111 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 111
# trial cap = 56
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-02_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-02_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-02_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 102
# trial cap = 51
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 60
# trial cap = 30
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-014_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 145 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 145
# trial cap = 72
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-02_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-02_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-02_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 118 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 118
# trial cap = 59
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-004_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-004_ses-01_task-vp_run-1_eeg_epochs.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-004_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
# Not setting metadata
# 36 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 36
# trial cap = 18
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-008_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-008_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-008_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 117 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 117
# trial cap = 58
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-018_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-018_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-018_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 117 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 117
# trial cap = 58
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-006_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 118 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 118
# trial cap = 59
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-032_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-032_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-032_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 113 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 113
# trial cap = 56
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-012_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-012_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-012_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 99
# trial cap = 50
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 98 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 98
# trial cap = 49
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-017_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-017_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-017_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 89
# trial cap = 44
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-096_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-096_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-096_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 119 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 119
# trial cap = 60
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-02_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-02_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-02_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 119 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 119
# trial cap = 60
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-01_task-vp_run-1_eeg_epochs.fif ...
#     Found the data of interest:
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-002_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 39 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 39
# trial cap = 20
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-024_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-024_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-024_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 117 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 117
# trial cap = 58
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-028_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-028_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-028_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 86 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 86
# trial cap = 43
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-02_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-02_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-052_ses-02_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 97 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 97
# trial cap = 48
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-009_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-009_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-009_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 100
# trial cap = 50
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-023_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-023_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-023_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 114 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 114
# trial cap = 57
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-029_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-029_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-029_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 89
# trial cap = 44
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-02_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-02_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-038_ses-02_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 96 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 96
# trial cap = 48
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-013_ses-01_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-013_ses-01_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-013_ses-01_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 105 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 105
# trial cap = 52
# /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-02_task-vp_run-1_eeg_epochs.fif
# Reading /home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-02_task-vp_run-1_eeg_epochs.fif ...
# /tmp/ipykernel_33495/1439447813.py:6: RuntimeWarning: This filename (/home/james/q1k/pilot/q1k-external-pilot/derivatives/pylossless/derivatives/q1k_postproc/epoch_fif_files/vp/sub-010_ses-02_task-vp_run-1_eeg_epochs.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   new_epoch = mne.read_epochs(filepath)
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 116 matching events found
# No baseline correction applied
# 0 projection items activated
# NTrials = 116
# trial cap = 58

# %%
def condition_summary(condition_label):
    print('Working on: ', condition_label)
    grand_average = mne.grand_average([item[0] for item in averaging_dict[condition_label]])
    display(grand_average)
    grand_average.plot()
    times = np.arange(-1.0, 2.0, .1)
    fig = grand_average.plot_topomap(times=times, colorbar=True)
    fig.suptitle(condition_label)

for condition in conditions:
    condition_summary(condition)
# Out:
# Working on:  sv06
# Identifying common channels ...
# <Evoked | 'Grand average (n = 27)' (average, N=27), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>
# /tmp/ipykernel_33495/3457014730.py:7: RuntimeWarning: More than 25 topomaps plots requested. This might take a while.
#   fig = grand_average.plot_topomap(times=times, colorbar=True)
# <MNEFigure size 4500x220 with 31 Axes>
# Working on:  sv15
# Identifying common channels ...
# <Evoked | 'Grand average (n = 27)' (average, N=27), -1 – 2 s, baseline -1 – 0 s, 129 ch, ~3.1 MB>
# /tmp/ipykernel_33495/3457014730.py:7: RuntimeWarning: More than 25 topomaps plots requested. This might take a while.
#   fig = grand_average.plot_topomap(times=times, colorbar=True)
# <MNEFigure size 4500x220 with 31 Axes>

# %%
color_dict = {'sv06':'blue', 'sv15':'red'}
linestyle_dict = {'sv06':'-', 'sv15':'-'}

evokeds = {
    'sv06': [item[0] for item in averaging_dict['sv06']],
    'sv15': [item[0] for item in averaging_dict['sv15']],
}

mne.viz.plot_compare_evokeds(evokeds,
                             combine='mean',
                             legend='lower right',
                             picks=roi, show_sensors='upper right',
                             colors=color_dict,
                             linestyles=linestyle_dict,
                             title='6Hz vs. 15Hz ERPs'
                            )
# Out:
# combining channels using "mean"
# /tmp/ipykernel_33495/137560192.py:9: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   mne.viz.plot_compare_evokeds(evokeds,
# combining channels using "mean"
# [<Figure size 800x600 with 2 Axes>]

# %%
# True for ERSP, False for ITC
def do_power_plotting(ersp=True):
    indexer = 1 if ersp else 2
    cond1 = mne.grand_average([item[indexer] for item in averaging_dict['sv06']])
    cond2 = mne.grand_average([item[indexer] for item in averaging_dict['sv15']])

    epochs_power_1 = np.array([item[indexer].data for item in averaging_dict['sv06']])[:, 0, :, :]
    epochs_power_2 = np.array([item[indexer].data for item in averaging_dict['sv15']])[:, 0, :, :]

    #times = 1e3 * epochs_power_1.times  # change unit to ms
    times = 1e3 * averaging_dict['sv06'][0][1].times
    fig1, (ax1t, ax1b) = plt.subplots(2, 1, figsize=(6, 4))
    fig1.subplots_adjust(0.12, 0.08, 0.96, 0.94, 0.2, 0.43)

    ax1t.imshow(
        epochs_power_1.mean(axis=0),
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="RdBu_r",
    )

    ax1b.imshow(
        epochs_power_2.mean(axis=0),
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="RdBu_r",
    )

    ax1t.set_ylabel("Frequency (Hz)")
    ax1t.set_title(f"target Induced power")
    ax1b.set_title(f"target Inter Trial Coherence")
    ax1b.set_xlabel("Time (ms)")


    F_obs, clusters, cluster_p_values, H0 = mne.stats.permutation_cluster_test(
        [epochs_power_1, epochs_power_2],
        out_type="mask",
        n_permutations=100,
        threshold=6.0,
        tail=0,
    ) # returns F difference, sampled, zscore

    # Grab any ERSP type timing window and use it to scale to ms
    times = 1e3 * averaging_dict['sv06'][0][1].times

    evoked_power_contrast = epochs_power_1.mean(axis=0) - epochs_power_2.mean(axis=0)
    signs = np.sign(evoked_power_contrast)

    F_obs_plot = np.nan * np.ones_like(F_obs)
    for c, p_val in zip(clusters, cluster_p_values):
        if p_val <= 0.05:
            F_obs_plot[c] = F_obs[c] * signs[c]
    max_F = np.nanmax(abs(F_obs_plot))

    fig, (ax, ax2) = plt.subplots(2, 1, figsize=(6, 4))
    ax.imshow(
        F_obs,
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="gray",
    )

    ax.imshow(
        F_obs_plot,
        extent=[times[0], times[-1], freqs[0], freqs[-1]],
        aspect="auto",
        origin="lower",
        cmap="RdBu_r",
        vmin=-max_F,
        vmax=max_F,
    )
    ax.set_xlabel("Time (ms)")
    ax.set_ylabel("Frequency (Hz)")
    ax.set_title("Induced power")

    evoked_contrast = mne.combine_evoked(
        [cond1, cond2], weights=[1, -1]
    )
    evoked_contrast.plot(axes=ax2)

# %%
do_power_plotting(ersp=True)
do_power_plotting(ersp=False)
# Out:
# Identifying common channels ...
# Identifying common channels ...
# stat_fun(H1): min=0.000000 max=3.267230
# Running initial clustering …
# Found 0 clusters
# No baseline correction applied
# /tmp/ipykernel_33495/3682000692.py:37: RuntimeWarning: No clusters found, returning empty H0, clusters, and cluster_pv
#   F_obs, clusters, cluster_p_values, H0 = mne.stats.permutation_cluster_test(
# /tmp/ipykernel_33495/3682000692.py:55: RuntimeWarning: All-NaN slice encountered
#   max_F = np.nanmax(abs(F_obs_plot))
# Identifying common channels ...
# Identifying common channels ...
# stat_fun(H1): min=0.000000 max=26.147179
# Running initial clustering …
# Found 30 clusters
# 100%|██████████| Permuting : 99/99 [00:03<00:00,   24.77it/s]
# No baseline correction applied

# %%
# !jupyter nbconvert --output {"session_reports/group_half-trials_vp.html"} --TagRemovePreprocessor.remove_all_outputs_tags='{"exclude"}' --no-input --to html group_erp_tf_vp.ipynb
# Out:
# [NbConvertApp] Converting notebook group_erp_tf_vp.ipynb to html
# [NbConvertApp] Writing 3181806 bytes to session_reports/group_half-trials_vp.html
